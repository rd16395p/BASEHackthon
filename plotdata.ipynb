# %%
import matplotlib.pyplot as plt
import seaborn
import pandas as pd
import os
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# %%
data = pd.read_csv('job_category_count.csv')

# %%
data.head()
# Out:
#                                          JobCategory    Job ID  #OfPositions  \
# 0                   Administration & Human Resources  53988739           324
# 1  Administration & Human Resources Building Oper...   3661567             9
# 2  Administration & Human Resources Building Oper...   1275216             3
# 3  Administration & Human Resources Communication...    699130             2
# 4  Administration & Human Resources Communication...    390626             1
#
#    Salary Range From  Salary Range To  Recruitment Contact
# 0       5.959887e+06     8.810725e+06                  NaN
# 1       5.103750e+05     7.118180e+05                  NaN
# 2       1.623000e+05     2.519430e+05                  NaN
# 3       7.450200e+04     1.169560e+05                  NaN
# 4       9.000000e+04     1.000000e+05                  NaN

# %%
data_plot1 = data.head(10)
print(data_plot)
# Out:
#                                          JobCategory    Job ID  #OfPositions  \
# 0                   Administration & Human Resources  53988739           324
# 1  Administration & Human Resources Building Oper...   3661567             9
# 2  Administration & Human Resources Building Oper...   1275216             3
# 3  Administration & Human Resources Communication...    699130             2
# 4  Administration & Human Resources Communication...    390626             1
# 5  Administration & Human Resources Communication...    806140             2
# 6  Administration & Human Resources Communication...    846044             4
# 7  Administration & Human Resources Communication...    413178             1
# 8  Administration & Human Resources Communication...    832404             2
# 9  Administration & Human Resources Constituent S...   3350902            12
#
#    Salary Range From  Salary Range To  Recruitment Contact
# 0       5.959887e+06     8.810725e+06                  NaN
# ...

# %%
y = seaborn.barplot(x = data_plot1['#OfPositions'],y=data_plot1['JobCategory'],data=data)
for index, value in enumerate(data_plot1['#OfPositions']):
    y.text(value , index + .15, str(value), fontweight='bold')

# %%
data_plot2 = data.tail(10)

# %%
y = seaborn.barplot(x = data_plot2['#OfPositions'],y=data_plot2['JobCategory'],data=data)
for index, value in enumerate(data_plot2['#OfPositions']):
    y.text(value , index + .15, str(value), fontweight='bold')

# %%
data_plot3 = data.sample(10)

# %%
y = seaborn.barplot(x = data_plot3['#OfPositions'],y=data_plot3['JobCategory'],data=data)
for index, value in enumerate(data_plot3['#OfPositions']):
    y.text(value , index + .15, str(value), fontweight='bold')
